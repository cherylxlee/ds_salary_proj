# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('salary_data_cleaned.csv')

# %%
df.head()
# Out:
#         Job Title               Salary Estimate  \
# 0  Data Scientist  $60K - $140K (Employer est.)
# 1  Data Scientist  $60K - $140K (Employer est.)
# 2  Data Scientist  $60K - $140K (Employer est.)
# 3  Data Scientist  $60K - $140K (Employer est.)
# 4  Data Scientist  $60K - $140K (Employer est.)
#
#                                      Job Description  Rating  \
# 0  We are looking for junior, mid-level or senior...    -1.0
# 1  Description: Would you like to join a rapidly ...     4.3
# 2  Do you have a passion for data science, machin...     4.3
# 3  Roles & Responsibilities: Provides support of ...    -1.0
# 4  Who May Apply\n\nJob Opening: 46673. Job Posti...     4.1
#
#                            Company Name        Location              Size  \
# 0            Tech brothers infoservices          Remote           Unknown
# 1                  ClassLink, Inc.\n4.3          Remote           Unknown
# 2                        Microsoft\n4.3   Cambridge, MA  10000+ Employees
# 3                            Ai Vantage          Remote           Unknown
# 4  Federal Bureau of Investigation\n4.1  Washington, DC  10000+ Employees
#
#    Founded  Type of ownership                       Industry  ... avg_salary  \
# 0       -1   Company - Public                        unknown  ...      100.0
# 1       -1  Company - Private        Internet & Web Services  ...      100.0
# 2     1975   Company - Public  Computer Hardware Development  ...      100.0
# 3       -1   Company - Public                        unknown  ...      100.0
# 4     1908         Government              National Agencies  ...      100.0
#
#                          Company_txt  Job_State  age_of_company  python_yn  \
# 0         Tech brothers infoservices     Remote              -1          1
# 1                  ClassLink, Inc.\n     Remote              -1          0
# 2                        Microsoft\n         MA              48          0
# 3                         Ai Vantage     Remote              -1          0
# 4  Federal Bureau of Investigation\n         DC             115          0
#
#   sql_yn excel_yn  spark_yn  aws_yn        job_simp
# 0      1        1         0       0  data scientist
# 1      0        0         0       0  data scientist
# 2      0        0         0       1  data scientist
# 3      0        0         0       0  data scientist
# 4      0        0         0       0  data scientist
#
# [5 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Size', 'Founded', 'Type of ownership',
#        'Industry', 'Sector', 'Revenue', 'min_salary', 'max_salary',
#        'avg_salary', 'Company_txt', 'Job_State', 'age_of_company', 'python_yn',
#        'sql_yn', 'excel_yn', 'spark_yn', 'aws_yn', 'job_simp'],
#       dtype='object')

# %%
def title_simplifier(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'data engineer' in title.lower():
        return 'data engineer'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'machine learning' in title.lower():
        return 'mle'
    elif 'manager' in title.lower():
        return 'manager'
    elif 'director' in title.lower():
        return 'director'
    else:
        return 'na'
    
def seniority(title):
    if 'sr' in title.lower() or 'senior' in title.lower() or 'sr' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower():
            return 'senior'
    elif 'jr' in title.lower() or 'jr.' in title.lower():
        return 'jr'
    else:
        return 'na'

# %%
df['job_simp'] = df['Job Title'].apply(title_simplifier)

# %%
df.job_simp.value_counts()
# Out:
# job_simp
# data scientist    478
# na                 12
# analyst             8
# data engineer       2
# Name: count, dtype: int64

# %%
df['seniority'] = df['Job Title'].apply(seniority)
df.seniority.value_counts()
# Out:
# seniority
# na        348
# senior    141
# jr         11
# Name: count, dtype: int64

# %%
# Revised dictionary with both full names and uppercase abbreviations
state_abbreviations = {
    'california': 'CA',
    'texas': 'TX',
    'alabama': 'AL',
    'illinois': 'IL',
    'new york state': 'NY',
    'virginia': 'VA',
    'massachusetts': 'MA',
    'maine': 'ME',
    'maryland': 'MD',
    'united states': 'USA',
}

# Apply lambda function to db
df['job_state'] = df['job_state'].apply(lambda x: state_abbreviations.get(x.strip().lower(), x.strip()))

# Count the values again
df.job_state.value_counts()
# Out:
# job_state
# CA        108
# Remote     98
# TX         48
# NY         39
# VA         23
# IL         22
# USA        17
# NJ         15
# MA         14
# FL         12
# NC         11
# WA         10
# MD          9
# CO          9
# MO          7
# MN          7
# DC          7
# GA          7
# MI          6
# CT          5
# AZ          4
# IN          4
# AL          3
# OH          3
# LA          2
# OR          2
# DE          1
# KY          1
# ME          1
# PA          1
# HI          1
# WI          1
# TN          1
# UT          1
# Name: count, dtype: int64

# %%
#  Job description length 
df['desc_len'] = df['Job Description'].apply(lambda x: len(x))
df['desc_len']
# Out:
# 0       544
# 1       778
# 2      1926
# 3      1474
# 4       655
#        ...
# 495    1274
# 496     830
# 497     756
# 498    1588
# 499     676
# Name: desc_len, Length: 500, dtype: int64

# %%
df['Company_txt'] = df.Company_txt.apply(lambda x: x.replace('\n', ''))

# %%
df['Company_txt']
# Out:
# 0                Tech brothers infoservices
# 1                           ClassLink, Inc.
# 2                                 Microsoft
# 3                                Ai Vantage
# 4           Federal Bureau of Investigation
#                        ...
# 495                             Freddie Mac
# 496                                Hatch IT
# 497                                 Verizon
# 498    Teachers College Columbia University
# 499                        Restaurant Depot
# Name: Company_txt, Length: 500, dtype: object

# %%
df.describe()
# Out:
#            Rating      Founded  min_salary  max_salary  avg_salary  \
# count  500.000000   500.000000  500.000000  500.000000  500.000000
# mean     3.330800  1590.388000  110.060000  183.380000  146.720000
# std      1.632943   782.937384   31.721111   81.573919   53.963002
# min     -1.000000    -1.000000   50.000000   80.000000   65.000000
# 25%      3.500000  1884.500000   92.000000  130.000000  112.000000
# 50%      3.900000  1977.500000  112.000000  143.000000  126.500000
# 75%      4.100000  2006.000000  140.000000  218.000000  165.000000
# max      5.000000  2022.000000  153.000000  332.000000  242.500000
#
#        age_of_company   python_yn      sql_yn    excel_yn    spark_yn  \
# count      500.000000  500.000000  500.000000  500.000000  500.000000
# mean        39.762000    0.110000    0.090000    0.112000    0.026000
# std         51.056389    0.313203    0.286468    0.315682    0.159295
# min         -1.000000    0.000000    0.000000    0.000000    0.000000
# 25%          7.000000    0.000000    0.000000    0.000000    0.000000
# 50%         21.000000    0.000000    0.000000    0.000000    0.000000
# 75%         53.250000    0.000000    0.000000    0.000000    0.000000
# max        333.000000    1.000000    1.000000    1.000000    1.000000
#
#            aws_yn     desc_len
# count  500.000000   500.000000
# mean     0.054000  1276.774000
# std      0.226244  1135.950018
# min      0.000000    81.000000
# 25%      0.000000   707.000000
# 50%      0.000000   916.500000
# 75%      0.000000  1310.500000
# max      1.000000  7972.000000

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Size', 'Founded', 'Type of ownership',
#        'Industry', 'Sector', 'Revenue', 'min_salary', 'max_salary',
#        'avg_salary', 'Company_txt', 'Job_State', 'age_of_company', 'python_yn',
#        'sql_yn', 'excel_yn', 'spark_yn', 'aws_yn', 'job_simp', 'seniority',
#        'job_state', 'desc_len'],
#       dtype='object')

# %%
df.Rating.hist()
# Out:
# <Axes: >

# %%
df.avg_salary.hist()
# Out:
# <Axes: >

# %%
df.age_of_company.hist()
# Out:
# <Axes: >

# %%
df.desc_len.hist()
# Out:
# <Axes: >

# %%
df.boxplot(column = ['age_of_company','avg_salary','Rating'])
# Out:
# <Axes: >

# %%
df.boxplot(column = 'Rating')
# Out:
# <Axes: >

# %%
df[['age_of_company','avg_salary','Rating','desc_len']].corr()
# Out:
#                 age_of_company  avg_salary    Rating  desc_len
# age_of_company        1.000000    0.025844  0.258850 -0.008694
# avg_salary            0.025844    1.000000  0.095370  0.053233
# Rating                0.258850    0.095370  1.000000  0.103084
# desc_len             -0.008694    0.053233  0.103084  1.000000

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(df[['age_of_company','avg_salary','Rating','desc_len']].corr(),vmax=.3, center=0, cmap=cmap,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Size', 'Founded', 'Type of ownership',
#        'Industry', 'Sector', 'Revenue', 'min_salary', 'max_salary',
#        'avg_salary', 'Company_txt', 'Job_State', 'age_of_company', 'python_yn',
#        'sql_yn', 'excel_yn', 'spark_yn', 'aws_yn', 'job_simp', 'seniority',
#        'job_state', 'desc_len'],
#       dtype='object')

# %%
df_cat = df[['Location', 'Size','Type of ownership', 'Industry', 'Sector', 'Revenue', 'Company_txt', 'job_state', 'python_yn', 'sql_yn',
       'spark_yn', 'aws_yn', 'excel_yn', 'job_simp', 'seniority']]

# %%
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location: total = 165
# graph for Size: total = 9
# graph for Type of ownership: total = 12
# graph for Industry: total = 59
# graph for Sector: total = 23
# graph for Revenue: total = 11
# graph for Company_txt: total = 416
# graph for job_state: total = 34
# graph for python_yn: total = 2
# graph for sql_yn: total = 2
# graph for spark_yn: total = 2
# graph for aws_yn: total = 2
# graph for excel_yn: total = 2
# graph for job_simp: total = 4
# graph for seniority: total = 3

# %%
for i in df_cat[['Location','Company_txt']].columns:
    cat_num = df_cat[i].value_counts()[:20]
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location: total = 20
# graph for Company_txt: total = 20

# %%
pd.pivot_table(df, index = 'job_simp', values = 'avg_salary')
# Out:
#                 avg_salary
# job_simp
# analyst         145.000000
# data engineer   157.000000
# data scientist  146.890167
# na              139.375000

# %%
pd.pivot_table(df, index = ['job_simp','seniority'], values = 'avg_salary')
# Out:
#                           avg_salary
# job_simp       seniority
# analyst        jr          76.250000
#                na         167.916667
# data engineer  na         165.000000
#                senior     149.000000
# data scientist jr         147.500000
#                na         141.993921
#                senior     158.357143
# na             na         139.375000

# %%
pd.pivot_table(df, index = ['job_state','job_simp'], values = 'avg_salary').sort_values('job_state', ascending = False)
# Out:
#                           avg_salary
# job_state job_simp
# WI        data scientist  149.000000
# WA        data scientist  158.850000
# VA        data scientist  148.333333
#           analyst         186.750000
# UT        data scientist  115.500000
# USA       data scientist  151.500000
# TX        na               87.500000
#           data scientist  138.968085
# TN        data scientist  115.500000
# Remote    data scientist  133.853261
#           analyst          76.250000
#           data engineer   149.000000
#           na              186.500000
# PA        data scientist   87.500000
# OR        data scientist  179.000000
# OH        na               65.000000
#           data scientist  184.500000
# NY        na              195.750000
#           data scientist  163.932432
# NJ        data scientist  131.733333
# NC        data scientist  136.900000
#           analyst         149.000000
# MO        data scientist  160.642857
# MN        data scientist  155.500000
#           analyst         242.500000
# MI        na               65.000000
#           data scientist  153.900000
# ME        data scientist   87.500000
# MD        data scientist  156.777778
# MA        data scientist  135.000000
#           data engineer   165.000000
# LA        data scientist  195.750000
# KY        data scientist  118.000000
# IN        data scientist  179.375000
# IL        data scientist  168.500000
# HI        data scientist  224.500000
# GA        data scientist  142.285714
# FL        data scientist  149.500000
#           analyst         118.000000
# DE        data scientist   65.000000
# DC        data scientist  157.071429
# CT        data scientist  119.200000
# CO        data scientist  155.055556
# CA        na              143.500000
#           data scientist  149.095238
#           analyst         124.500000
# AZ        data scientist  161.000000
# AL        na              108.500000
#           data scientist  149.000000

# %%
pd.options.display.max_rows
pd.set_option('display.max_rows', None)

# %%
60
# Out:
# 60

# %%
pd.pivot_table(df, index = ['job_state','job_simp'], values = 'avg_salary', aggfunc = 'count').sort_values('job_state', ascending = False)
# Out:
#                           avg_salary
# job_state job_simp
# WI        data scientist           1
# WA        data scientist          10
# VA        data scientist          21
#           analyst                  2
# UT        data scientist           1
# USA       data scientist          17
# TX        na                       1
#           data scientist          47
# TN        data scientist           1
# Remote    data scientist          92
#           analyst                  2
#           data engineer            1
#           na                       3
# PA        data scientist           1
# OR        data scientist           2
# OH        na                       1
#           data scientist           2
# NY        na                       2
#           data scientist          37
# NJ        data scientist          15
# NC        data scientist          10
#           analyst                  1
# MO        data scientist           7
# MN        data scientist           6
#           analyst                  1
# MI        na                       1
#           data scientist           5
# ME        data scientist           1
# MD        data scientist           9
# MA        data scientist          13
#           data engineer            1
# LA        data scientist           2
# KY        data scientist           1
# IN        data scientist           4
# IL        data scientist          22
# HI        data scientist           1
# GA        data scientist           7
# FL        data scientist          11
#           analyst                  1
# DE        data scientist           1
# DC        data scientist           7
# CT        data scientist           5
# CO        data scientist           9
# CA        na                       2
#           data scientist         105
#           analyst                  1
# AZ        data scientist           4
# AL        na                       2
#           data scientist           1

# %%
pd.pivot_table(df[df.job_simp == 'data scientist'], index = 'job_state', values = 'avg_salary').sort_values('avg_salary', ascending = False)
# Out:
#            avg_salary
# job_state
# HI         224.500000
# LA         195.750000
# OH         184.500000
# IN         179.375000
# OR         179.000000
# IL         168.500000
# NY         163.932432
# AZ         161.000000
# MO         160.642857
# WA         158.850000
# DC         157.071429
# MD         156.777778
# MN         155.500000
# CO         155.055556
# MI         153.900000
# USA        151.500000
# FL         149.500000
# CA         149.095238
# AL         149.000000
# WI         149.000000
# VA         148.333333
# GA         142.285714
# TX         138.968085
# NC         136.900000
# MA         135.000000
# Remote     133.853261
# NJ         131.733333
# CT         119.200000
# KY         118.000000
# TN         115.500000
# UT         115.500000
# ME          87.500000
# PA          87.500000
# DE          65.000000

# %%
# rating, industry, sector, revenue, python, sql, spark, aws, excel, desc_len, Type of onwership

# %%
df_pivots = df[['Rating', 'Industry', 'Sector', 'Revenue', 'python_yn', 'sql_yn', 'spark_yn', 'aws_yn', 'excel_yn', 'Type of ownership','avg_salary']]

# %%
for i in df_pivots.columns:
    print(i)
    print(pd.pivot_table(df_pivots,index =i, values = 'avg_salary').sort_values('avg_salary', ascending = False))
# Out:
# Rating
#         avg_salary
# Rating
#  2.7    242.500000
#  4.6    206.300000
#  3.5    175.074074
#  3.8    160.222222
#  4.8    159.333333
#  3.6    158.125000
#  3.4    152.891304
#  4.2    151.950000
#  2.8    150.500000
#  3.9    149.637255
#  4.0    147.921569
#  3.0    146.700000
#  4.9    146.642857
#  4.3    143.603448
#  2.6    143.500000
#  3.3    142.187500
#  3.7    141.400000
#  4.5    140.600000
#  4.1    140.118421
#  2.9    139.312500
#  5.0    132.500000
# -1.0    131.741379
#  4.7    130.750000
#  3.1    125.785714
#  4.4    122.863636
#  2.4    118.000000
#  2.3    112.000000
#  3.2    110.666667
#  2.0     76.250000
# Industry
#                                           avg_salary
# Industry
# Shipping & Trucking                       242.500000
# Primary & Secondary Schools               242.500000
# Health Care Products Manufacturing        224.500000
# Home Furniture & Housewares Stores        222.000000
# Other Retail Stores                       209.833333
# Municipal Agencies                        195.750000
# Real Estate                               188.125000
# Wholesale                                 187.375000
# Insurance Agencies & Brokerages           185.500000
# Beauty & Personal Accessories Stores      183.500000
# Broadcast Media                           171.125000
# Travel Agencies                           169.750000
# Business Consulting                       169.218750
# Software Development                      168.115385
# Machinery Manufacturing                   166.700000
# Food & Beverage Manufacturing             164.625000
# Advertising & Public Relations            164.100000
# Telecommunications Services               158.916667
# National Agencies                         157.714286
# Computer Hardware Development             156.523256
# Insurance Carriers                        156.050000
# Department, Clothing & Shoe Stores        153.800000
# Health Care Services & Hospitals          152.692308
# Pet & Pet Supplies Stores                 152.000000
# Investment & Asset Management             151.600000
# Chemical Manufacturing                    150.125000
# Security & Protective                     149.000000
# Banking & Lending                         147.928571
# Restaurants & Cafes                       147.875000
# Internet & Web Services                   147.285714
# Enterprise Software & Network Solutions   147.275862
# Energy & Utilities                        146.937500
# Biotech & Pharmaceuticals                 145.727273
# Financial Transaction Processing          143.333333
# Video Game Publishing                     140.750000
# Information Technology Support Services   140.465116
# Publishing                                140.000000
# Consumer Product Manufacturing            132.055556
# Colleges & Universities                   130.937500
# Aerospace & Defense                       130.500000
# unknown                                   129.187500
# Hotels & Resorts                          128.800000
# Vehicle Dealers                           124.500000
# Stock Exchanges                           124.500000
# Transportation Equipment Manufacturing    123.800000
# Accounting & Tax                          123.400000
# Research & Development                    123.285714
# Electronics Manufacturing                 121.333333
# Film Production                           121.000000
# General Merchandise & Superstores         120.000000
# Construction                              118.250000
# Grantmaking & Charitable Foundations      118.000000
# Consumer Electronics & Appliances Stores  116.750000
# Staffing & Subcontracting                 116.166667
# Legal                                     109.000000
# Grocery Stores                            105.500000
# Rail Transportation                        87.500000
# Education & Training Services              65.000000
# Airlines, Airports & Air Transportation    65.000000
# Sector
#                                              avg_salary
# Sector
# Real Estate                                  188.125000
# Government & Public Administration           166.166667
# Retail & Wholesale                           163.295455
# Insurance                                    160.958333
# Telecommunications                           158.916667
# Management & Consulting                      154.979167
# Media & Communication                        154.159091
# Healthcare                                   152.692308
# Information Technology                       149.320652
# Restaurants & Food Service                   147.875000
# Hotels & Travel Accommodation                147.000000
# Energy, Mining & Utilities                   146.937500
# Pharmaceutical & Biotechnology               145.727273
# Manufacturing                                144.790323
# Financial Services                           142.875000
# Education                                    135.500000
# Transportation & Logistics                   131.666667
# Aerospace & Defense                          130.500000
# unknown                                      129.187500
# Construction, Repair & Maintenance Services  118.250000
# Nonprofit & NGO                              118.000000
# Human Resources & Staffing                   116.166667
# Legal                                        109.000000
# Revenue
#                                   avg_salary
# Revenue
# $500 million to $1 billion (USD)  167.500000
# $5 to $10 billion (USD)           166.250000
# $1 to $5 billion (USD)            157.430556
# $100 to $500 million (USD)        153.230769
# $1 to $5 million (USD)            149.550000
# $10+ billion (USD)                146.504464
# Unknown / Non-Applicable          144.664835
# $25 to $100 million (USD)         141.295455
# -1                                133.040000
# $5 to $25 million (USD)           132.269231
# Less than $1 million (USD)        101.666667
# python_yn
#            avg_salary
# python_yn
# 0          149.420225
# 1          124.872727
# sql_yn
#         avg_salary
# sql_yn
# 0       148.127473
# 1       132.488889
# spark_yn
#           avg_salary
# spark_yn
# 0         146.786448
# 1         144.230769
# aws_yn
#         avg_salary
# aws_yn
# 1       149.314815
# 0       146.571882
# excel_yn
#           avg_salary
# excel_yn
# 0         148.926802
# 1         129.223214
# Type of ownership
#                                 avg_salary
# Type of ownership
# Hospital                        216.666667
# Private Practice / Firm         170.714286
# Nonprofit Organization          164.413043
# Government                      159.388889
# Subsidiary or Business Segment  157.772727
# Company - Public                147.035533
# Company - Private               143.707071
# College / University            140.357143
# Contract                        134.833333
# unknown                         133.040000
# Self-employed                   130.000000
# Unknown                          87.500000
# avg_salary
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[76], line 3
#       1 for i in df_pivots.columns:
#       2     print(i)
# ----> 3     print(pd.pivot_table(df_pivots,index =i, values = 'avg_salary').sort_values('avg_salary', ascending = False))
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\pivot.py:97, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      94     table = concat(pieces, keys=keys, axis=1)
#      95     return table.__finalize__(data, method="pivot_table")
# ---> 97 table = __internal_pivot_table(
#      98     data,
#      99     values,
#     100     index,
#     101     columns,
#     102     aggfunc,
#     103     fill_value,
#     104     margins,
#     105     dropna,
#     106     margins_name,
#     107     observed,
#     108     sort,
#     109 )
#     110 return table.__finalize__(data, method="pivot_table")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\pivot.py:166, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     163             pass
#     164     values = list(values)
# --> 166 grouped = data.groupby(keys, observed=observed, sort=sort)
#     167 agged = grouped.agg(aggfunc)
#     169 if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:8252, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8249     raise TypeError("You have to supply one of 'by' and 'level'")
#    8250 axis = self._get_axis_number(axis)
# -> 8252 return DataFrameGroupBy(
#    8253     obj=self,
#    8254     keys=by,
#    8255     axis=axis,
#    8256     level=level,
#    8257     as_index=as_index,
#    8258     sort=sort,
#    8259     group_keys=group_keys,
#    8260     observed=observed,
#    8261     dropna=dropna,
#    8262 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:931, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#     928 self.dropna = dropna
#     930 if grouper is None:
# --> 931     grouper, exclusions, obj = get_grouper(
#     932         obj,
#     933         keys,
#     934         axis=axis,
#     935         level=level,
#     936         sort=sort,
#     937         observed=observed,
#     938         dropna=self.dropna,
#     939     )
#     941 self.obj = obj
#     942 self.axis = obj._get_axis_number(axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\grouper.py:980, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#     976     in_axis, name, gpr = True, gpr, obj[gpr]
#     977     if gpr.ndim != 1:
#     978         # non-unique columns; raise here to get the name in the
#     979         # exception message
# --> 980         raise ValueError(f"Grouper for '{name}' not 1-dimensional")
#     981     exclusions.add(name)
#     982 elif obj._is_level_reference(gpr, axis=axis):
#
# ValueError: Grouper for 'avg_salary' not 1-dimensional

# %%
pd.pivot_table(df_pivots, index = 'Revenue', columns = 'python_yn', values = 'avg_salary', aggfunc = 'count')
# Out:
# python_yn                             0     1
# Revenue
# $1 to $5 billion (USD)             36.0   NaN
# $1 to $5 million (USD)              7.0   3.0
# $10+ billion (USD)                100.0  12.0
# $100 to $500 million (USD)         37.0   2.0
# $25 to $100 million (USD)          21.0   1.0
# $5 to $10 billion (USD)            23.0   5.0
# $5 to $25 million (USD)            24.0   2.0
# $500 million to $1 billion (USD)   13.0   1.0
# -1                                 21.0   4.0
# Less than $1 million (USD)          4.0   2.0
# Unknown / Non-Applicable          159.0  23.0

# %%
# !pip install wordcloud

from pillow import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
# Out:
# Collecting wordcloud
#   Obtaining dependency information for wordcloud from https://files.pythonhosted.org/packages/34/ac/72a4e42e76bf549dfd91791a6b10a9832f046c1d48b5e778be9ec012aa47/wordcloud-1.9.2-cp311-cp311-win_amd64.whl.metadata
#   Downloading wordcloud-1.9.2-cp311-cp311-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\cheryl\anaconda3\lib\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in c:\users\cheryl\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\cheryl\anaconda3\lib\site-packages (from wordcloud) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\cheryl\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\cheryl\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\cheryl\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\cheryl\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\cheryl\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\cheryl\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\cheryl\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\cheryl\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.2-cp311-cp311-win_amd64.whl (151 kB)
#    ---------------------------------------- 0.0/151.4 kB ? eta -:--:--
#    ---------------------------------------- 0.0/151.4 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/151.4 kB ? eta -:--:--
#    ---------- ---------------------------- 41.0/151.4 kB 495.5 kB/s eta 0:00:01
#    ------------------------------------- -- 143.4/151.4 kB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 151.4/151.4 kB 1.1 MB/s eta 0:00:00
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.2
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[82], line 3
#       1 get_ipython().system('pip install wordcloud')
# ----> 3 from pillow import WordCloud, ImageColorGenerator, STOPWORDS
#       4 from nltk.corpus import stopwords
#       5 from nltk.tokenize import word_tokenize
#
# ModuleNotFoundError: No module named 'pillow'

# %%
words = " ".join(df['Job Description'])

def punctuation_stop(text):
    """remove punctuation and stop words"""
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered


words_filtered = punctuation_stop(words)

text = " ".join([ele for ele in words_filtered])

wc= WordCloud(background_color="white", random_state=1,stopwords=STOPWORDS, max_words = 2000, width =800, height = 1500)
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow(wc,interpolation="bilinear")
plt.axis('off')
plt.show()
